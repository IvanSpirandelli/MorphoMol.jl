# %%
import Pkg; 

if split(pwd(),"/")[end] == "assembly"
    cd(joinpath(@__DIR__, "../../"))
    Pkg.activate("Project.toml")
end

using MorphoMol

using JLD2
# Out:
#   Activating project at `~/Desktop/Doktor/MorphoMol/MorphoMolMonteCarlo`

# %%
for file in readdir("hpc/assembly/6sag_protor_oj_0_0_os_0_85")
    @load "hpc/assembly/6sag_protor_oj_0_0_os_0_85/$file" in_out_data
    #println("$(in_out_data.output.Es[1]), $(minimum(in_out_data.output.Es)), $(in_out_data.output.Es[end])")
    println(in_out_data.input.)
    break
end
# Out:
# MorphoMol.Algorithms.MorphometricSimulationInput([28.738987272237953 27.903855971533442 27.701609616151966 28.43313942925287 28.520708963426962 29.67868566080619 26.694480519011787 26.497514648784907 27.274807999193804 27.499358647450666 25.014780834108436 24.208287307570245 24.471389792374964 23.169464233608622 23.72904443051641 22.421505976866882 22.704242785180465 21.95739258210639 27.684009622445018 28.455079601534326 27.553431282232495 27.32253608976668 29.706594716415392 29.372189979493253 27.04155181365666 26.213057600830048 27.09765833337442 27.999751503934704 25.449162227731524 24.557082790857024 24.627633159961615 23.877394473228353 26.845081588217877 27.591477646126503 26.75140864644044 27.258401063520154 28.20187512735482 27.159112038274102 29.031222226944475 25.485699741916022 24.579306509261922 23.500335901426215 22.97813276688901 23.9219042505486 24.897985933655235 23.360463962655494 23.152502214424754 22.083270671558758 20.71555454568332 19.819103667851177 22.07683333
# ...

# %%
MorphoMol.Utilities.state_to_poly(get_flat_realization(state, template_mol), radii, "assets/output/$(i)", n_mol, n_atoms_per_mol)
